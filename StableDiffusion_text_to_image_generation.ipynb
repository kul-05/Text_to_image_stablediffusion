# %%
! pip install diffusers transformers gradio accelerate matplotlib torch

# %%
from diffusers import StableDiffusionPipeline
import matplotlib.pyplot as plt
import torch

# %%
authorization_token = "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"
model_id = "CompVis/stable-diffusion-v1-4"
device = "cuda"

# %%
import torch
from diffusers import StableDiffusionPipeline
from torch import autocast

model_id = "CompVis/stable-diffusion-v1-4"
device = "cuda"


pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16,use_auth_token=authorization_token)
pipe.to(device)
# Out:
# Keyword arguments {'use_auth_token': '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'} are not expected by StableDiffusionPipeline and will be ignored.
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# StableDiffusionPipeline {
#   "_class_name": "StableDiffusionPipeline",
#   "_diffusers_version": "0.29.0",
#   "_name_or_path": "CompVis/stable-diffusion-v1-4",
#   "feature_extractor": [
#     "transformers",
#     "CLIPImageProcessor"
#   ],
#   "image_encoder": [
#     null,
#     null
#   ],
#   "requires_safety_checker": true,
#   "safety_checker": [
#     "stable_diffusion",
#     "StableDiffusionSafetyChecker"
#   ],
#   "scheduler": [
#     "diffusers",
#     "PNDMScheduler"
#   ],
#   "text_encoder": [
#     "transformers",
#     "CLIPTextModel"
#   ],
#   "tokenizer": [
#     "transformers",
#     "CLIPTokenizer"
#   ],
#   "unet": [
#     "diffusers",
#     "UNet2DConditionModel"
#   ],
#   "vae": [
#     "diffusers",
#     "AutoencoderKL"
#   ]
# }

# %%
prompt = """astronaut sitting on a horse in space
"""

# %%
image = pipe(prompt).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
print("[PROMPT]: ",prompt)
plt.imshow(image);
plt.axis('on');
# Out:
# [PROMPT]:  astronaut sitting on a horse in space

# %%
prompt = """girl seeing mountains and sunset
"""

# %%
image = pipe(prompt).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
print("[PROMPT]: ",prompt)
plt.imshow(image);
plt.axis('on');
# Out:
# [PROMPT]:  girl seeing mountains and sunset

# %%
prompt = """dog wearing sunglasses
"""

# %%
image = pipe(prompt).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
print("[PROMPT]: ",prompt)
plt.imshow(image);
plt.axis('on');
# Out:
# [PROMPT]:  dog wearing sunglasses

# %%
prompt = """lion drinking milk
"""

# %%
image = pipe(prompt).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
print("[PROMPT]: ",prompt)
plt.imshow(image);
plt.axis('on');
# Out:
# [PROMPT]:  lion drinking milk

# %%
prompt = "A futuristic cityscape at sunset"
image = pipe(prompt).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
plt.imshow(image);
plt.axis('on');
